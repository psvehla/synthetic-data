# %%
from faker import Faker

fake = Faker()

for i in range(100):
    print(f"Name: {fake.name()} | Account number: {fake.random_int()} | Address: {fake.address()}")
# Out:
# Name: Christine Mayo | Account number: 4368 | Address: 931 Fuller Track Apt. 876
# Aguirreport, AK 08564
# Name: Matthew Wilson | Account number: 8311 | Address: 015 Wilson Dam Apt. 822
# New Tashaport, OR 66510
# Name: Joshua Ramos | Account number: 2705 | Address: 1118 Paul Ville Suite 454
# Wilsonshire, NV 63522
# Name: Daniel Campos | Account number: 696 | Address: 8580 Cortez Trail
# Jasontown, VA 69763
# Name: Larry Martin | Account number: 1912 | Address: 93272 Young Fort
# Anthonyton, MI 42622
# Name: Whitney Jenkins | Account number: 1527 | Address: 6572 Valdez Hill
# Lake Jenniferport, OR 48977
# Name: Mandy Clark | Account number: 3349 | Address: 54120 Ortiz Mountains
# Lindseytown, PA 59511
# Name: Justin Vaughn | Account number: 3183 | Address: 265 Brittany Mews
# South Jeffrey, FL 98340
# Name: Scott Brewer | Account number: 7811 | Address: 2226 Peter Lock Suite 915
# New Chelseyburgh, MD 07615
# Name: Michael Yates | Account number: 3848 | Address: 525 Brown Villages
# ...
